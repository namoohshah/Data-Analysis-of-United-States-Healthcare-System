# %%
import pandas as pd

# %%
df = pd.read_csv('Healthcare Data.csv')

# %%
df.shape
# Out:
# (163065, 19)

# %%
df.columns
# Out:
# Index(['DRG Definition', 'Provider Id', 'Provider Name',
#        'Provider Street Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'Hospital Referral Region Description',
#        'Total Discharges', 'Average Covered Charges', 'Average Total Payments',
#        'Average Medicare Payments', 'Summary Level', 'State', 'State FIPS',
#        'Insured Males 18-25', 'Noninsured Males 18-25',
#        'Females 18-25 with Insurance', 'Females 18-25 without insurance'],
#       dtype='object')

# %%
df.dtypes
# Out:
# DRG Definition                          object
# Provider Id                              int64
# Provider Name                           object
# Provider Street Address                 object
# Provider City                           object
# Provider State                          object
# Provider Zip Code                        int64
# Hospital Referral Region Description    object
# Total Discharges                        object
# Average Covered Charges                 object
# Average Total Payments                  object
# Average Medicare Payments               object
# Summary Level                            int64
# State                                   object
# State FIPS                               int64
# Insured Males 18-25                     object
# Noninsured Males 18-25                  object
# Females 18-25 with Insurance            object
# Females 18-25 without insurance         object
# dtype: object

# %%
df.isna().sum()
# Out:
# DRG Definition                          0
# Provider Id                             0
# Provider Name                           0
# Provider Street Address                 0
# Provider City                           0
# Provider State                          0
# Provider Zip Code                       0
# Hospital Referral Region Description    0
# Total Discharges                        0
# Average Covered Charges                 0
# Average Total Payments                  0
# Average Medicare Payments               0
# Summary Level                           0
# State                                   0
# State FIPS                              0
# Insured Males 18-25                     0
# Noninsured Males 18-25                  0
# Females 18-25 with Insurance            0
# Females 18-25 without insurance         0
# dtype: int64

# %%
df['Insured Males 18-25'] = (df['Insured Males 18-25']).str.replace(',', '').astype(float)

# %%
type(df['Insured Males 18-25'][0])
# Out:
# numpy.float64

# %%
df['Females 18-25 with Insurance'] = (df['Females 18-25 with Insurance']).str.replace(',', '').astype(float)

# %%
df['total number of insurance'] = df['Insured Males 18-25'] + df['Females 18-25 with Insurance']
df
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        20017
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        30002
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        40004
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50006
# ...                                          ...          ...
# 163060  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50036
# 163061  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50026
# 163062  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50017
# 163063  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50013
# 163064  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50007
#
#                                      Provider Name  \
# 0                 SOUTHEAST ALABAMA MEDICAL CENTER
# 1                         ALASKA REGIONAL HOSPITAL
# 2             BANNER GOOD SAMARITAN MEDICAL CENTER
# ...

# %%
purpose_insured_people = df. groupby(by='DRG Definition')['total number of insurance'].sum()
purpose_insured_people
# Out:
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                                     9.437433e+08
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC                          1.152181e+09
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC                   1.638518e+09
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC                    2.151882e+09
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC              1.680119e+09
#                                                                                  ...
# 885 - PSYCHOSES                                                              5.208992e+08
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHABILITATION THERAPY W/O MCC    8.044126e+08
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                               7.749146e+08
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                             1.231151e+09
# ...

# %%
purpose_insured_people.to_csv('purpose_insured_people.csv')

# %%
df['Noninsured Males 18-25'] = (df['Noninsured Males 18-25']).str.replace(',', '').astype(float)

# %%
df['Females 18-25 without insurance'] = (df['Females 18-25 without insurance']).str.replace(',', '').astype(float)

# %%
df['total number of male'] = df['Insured Males 18-25'] + df['Noninsured Males 18-25']
df
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        20017
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        30002
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        40004
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50006
# ...                                          ...          ...
# 163060  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50036
# 163061  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50026
# 163062  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50017
# 163063  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50013
# 163064  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50007
#
#                                      Provider Name  \
# 0                 SOUTHEAST ALABAMA MEDICAL CENTER
# 1                         ALASKA REGIONAL HOSPITAL
# 2             BANNER GOOD SAMARITAN MEDICAL CENTER
# ...

# %%
purpose_male = df. groupby(by='DRG Definition')['total number of male'].sum()
purpose_male
# Out:
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                                     6.198744e+08
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC                          7.449225e+08
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC                   1.071900e+09
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC                    1.409557e+09
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC              1.100400e+09
#                                                                                  ...
# 885 - PSYCHOSES                                                              3.387141e+08
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHABILITATION THERAPY W/O MCC    5.106723e+08
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                               5.107545e+08
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                             8.015299e+08
# ...

# %%
purpose_male.to_csv('purpose_male.csv')

# %%
df['total number of female'] = df['Females 18-25 with Insurance'] + df['Females 18-25 without insurance']
df
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        20017
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        30002
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        40004
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50006
# ...                                          ...          ...
# 163060  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50036
# 163061  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50026
# 163062  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50017
# 163063  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50013
# 163064  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50007
#
#                                      Provider Name  \
# 0                 SOUTHEAST ALABAMA MEDICAL CENTER
# 1                         ALASKA REGIONAL HOSPITAL
# 2             BANNER GOOD SAMARITAN MEDICAL CENTER
# ...

# %%
purpose_female = df. groupby(by='DRG Definition')['total number of female'].sum()
purpose_female
# Out:
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                                     6.118080e+08
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC                          7.362399e+08
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC                   1.056494e+09
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC                    1.389903e+09
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC              1.085461e+09
#                                                                                  ...
# 885 - PSYCHOSES                                                              3.341743e+08
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHABILITATION THERAPY W/O MCC    5.046754e+08
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                               5.034969e+08
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                             7.916364e+08
# ...

# %%
purpose_female.to_csv('purpose_female.csv')

# %%
df['total number of uninsured'] = df['Noninsured Males 18-25'] + df['Females 18-25 without insurance']
df
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        20017
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        30002
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        40004
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50006
# ...                                          ...          ...
# 163060  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50036
# 163061  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50026
# 163062  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50017
# 163063  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50013
# 163064  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50007
#
#                                      Provider Name  \
# 0                 SOUTHEAST ALABAMA MEDICAL CENTER
# 1                         ALASKA REGIONAL HOSPITAL
# 2             BANNER GOOD SAMARITAN MEDICAL CENTER
# ...

# %%
purpose_uninsured_people = df. groupby(by='DRG Definition')['total number of uninsured'].sum()
purpose_uninsured_people
# Out:
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                                     287939028.0
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC                          328981271.0
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC                   489875728.0
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC                    647578373.0
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC              505742211.0
#                                                                                 ...
# 885 - PSYCHOSES                                                              151989187.0
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHABILITATION THERAPY W/O MCC    210935039.0
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                               239336853.0
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                             362014892.0
# ...

# %%
purpose_uninsured_people.to_csv('purpose_uninsured_people.csv')

# %%
df['Females 18-25 with Insurance'] = (df['Females 18-25 with Insurance']).apply(str).str.replace(',', '').astype(float)

# %%
df['Females 18-25 without insurance'] = (df['Females 18-25 without insurance']).apply(str).str.replace(',', '').astype(float)

# %%
df.sort_values("State",ascending=True)
# Out:
#                                           DRG Definition  Provider Id  \
# 2755                   291 - HEART FAILURE & SHOCK W MCC        20012
# 9538   178 - RESPIRATORY INFECTIONS & INFLAMMATIONS W CC        20001
# 9487   178 - RESPIRATORY INFECTIONS & INFLAMMATIONS W CC        20006
# 9436   178 - RESPIRATORY INFECTIONS & INFLAMMATIONS W CC        20026
# 9385         189 - PULMONARY EDEMA & RESPIRATORY FAILURE        20001
# ...                                                  ...          ...
# 9485   392 - ESOPHAGITIS, GASTROENT & MISC DIGEST DIS...       530025
# 11780   329 - MAJOR SMALL & LARGE BOWEL PROCEDURES W MCC       530012
# 12180                                   313 - CHEST PAIN       530012
# 8873   418 - LAPAROSCOPIC CHOLECYSTECTOMY W/O C.D.E. ...       530014
# 4130   641 - MISC DISORDERS OF NUTRITION,METABOLISM,F...       530012
#
#                           Provider Name    Provider Street Address  \
# ...

# %%
df['Average Total Payments'] = (df['Average Total Payments']).str.replace(',', '').astype(float)

# %%
purpose_discharge_payment = df.groupby(by=['Total Discharges','DRG Definition'])['Average Total Payments'].sum()
purpose_discharge_payment
# Out:
# Total Discharges  DRG Definition
# 1,022             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC      11265.01
# 1,028             885 - PSYCHOSES                                                                7721.30
# 1,031             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC      15631.40
# 1,032             470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC      12134.88
# 1,050             885 - PSYCHOSES                                                                9056.66
#                                                                                                  ...
# 99                871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HOURS W MCC                     185179.25
#                   872 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HOURS W/O MCC                    54242.13
#                   885 - PSYCHOSES                                                                5464.22
# ...

# %%
purpose_discharge_payment.to_csv('purpose_discharge_payment.csv')

# %%
df['Total Discharges'] = (df['Total Discharges']).str.replace(',', '').astype(float)

# %%
set(df['total number of uninsured'].to_list())
# Out:
# {5754.0,
#  5864.0,
#  11044.0,
#  11654.0,
#  11749.0,
#  13321.0,
#  16177.0,
#  17413.0,
#  18514.0,
#  18637.0,
#  20427.0,
#  24336.0,
#  31700.0,
#  35656.0,
#  36411.0,
#  39085.0,
#  40492.0,
#  43192.0,
#  53871.0,
#  59856.0,
#  61414.0,
#  61502.0,
#  71147.0,
#  73847.0,
#  75097.0,
#  76482.0,
#  81224.0,
#  86162.0,
#  87392.0,
#  96986.0,
#  106483.0,
#  106993.0,
#  107951.0,
#  120101.0,
#  121760.0,
#  126831.0,
#  133525.0,
#  136064.0,
#  143658.0,
#  145820.0,
#  163543.0,
#  164888.0,
#  169897.0,
#  172333.0,
#  219792.0,
#  227666.0,
#  275043.0,
#  277445.0,
#  525242.0,
#  900318.0,
#  919035.0}

# %%
purpose_discharge_payment = df.groupby(by=['total number of uninsured','Total Discharges'])['DRG Definition'].sum()
purpose_discharge_payment
# Out:
# total number of uninsured  Total Discharges
# 5754.0                     11.0                039 - EXTRACRANIAL PROCEDURES W/O CC/MCC309 - ...
#                            12.0                870 - SEPTICEMIA OR SEVERE SEPSIS W MV 96+ HOU...
#                            13.0                948 - SIGNS & SYMPTOMS W/O MCC918 - POISONING ...
#                            14.0                918 - POISONING & TOXIC EFFECTS OF DRUGS W/O M...
#                            15.0                918 - POISONING & TOXIC EFFECTS OF DRUGS W/O M...
#                                                                      ...
# 919035.0                   878.0               470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...
#                            883.0                                                 885 - PSYCHOSES
#                            922.0               470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT ...
# ...

# %%
purpose_uninsured_discharge
# Out:
# total number of uninsured  DRG Definition
# 5754.0                     039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                                        47.0
#                            057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC                            109.0
#                            064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC                     277.0
#                            065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC                      385.0
#                            066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC                209.0
#                                                                                                          ...
# 919035.0                   885 - PSYCHOSES                                                              10994.0
#                            897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHABILITATION THERAPY W/O MCC     2056.0
# ...

# %%
purpose_uninsured_discharge.to_csv('purpose_uninsured_discharge.csv')
